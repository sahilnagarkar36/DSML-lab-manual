# %% [markdown]
# <a href="https://colab.research.google.com/github/sahilnagarkar36/DSML-lab-manual/blob/main/DSML_NO3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import pandas as pd
import seaborn as sns

# %%
sales = pd.read_csv('/content/cosmeticsss.csv')

# %%
sales.describe()
# Out:
#              Price         Rank  Combination          Dry       Normal  \
# count  1472.000000  1472.000000   1472.00000  1472.000000  1472.000000
# mean     55.584239     4.153261      0.65625     0.614130     0.652174
# std      45.014429     0.633918      0.47512     0.486965     0.476442
# min       3.000000     0.000000      0.00000     0.000000     0.000000
# 25%      30.000000     4.000000      0.00000     0.000000     0.000000
# 50%      42.500000     4.300000      1.00000     1.000000     1.000000
# 75%      68.000000     4.500000      1.00000     1.000000     1.000000
# max     370.000000     5.000000      1.00000     1.000000     1.000000
#
#               Oily    Sensitive
# count  1472.000000  1472.000000
# mean      0.607337     0.513587
# std       0.488509     0.499985
# min       0.000000     0.000000
# 25%       0.000000     0.000000
# 50%       1.000000     1.000000
# 75%       1.000000     1.000000
# max       1.000000     1.000000

# %%
sales.count()
# Out:
# Label          1472
# Brand          1472
# Name           1472
# Price          1472
# Rank           1472
# Ingredients    1472
# Combination    1472
# Dry            1472
# Normal         1472
# Oily           1472
# Sensitive      1472
# dtype: int64

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1472 entries, 0 to 1471
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Label        1472 non-null   object
#  1   Brand        1472 non-null   object
#  2   Name         1472 non-null   object
#  3   Price        1472 non-null   int64
#  4   Rank         1472 non-null   float64
#  5   Ingredients  1472 non-null   object
#  6   Combination  1472 non-null   int64
#  7   Dry          1472 non-null   int64
#  8   Normal       1472 non-null   int64
#  9   Oily         1472 non-null   int64
#  10  Sensitive    1472 non-null   int64
# dtypes: float64(1), int64(6), object(4)
# memory usage: 126.6+ KB

# %%
sales.shape
# Out:
# (1472, 11)

# %%
plt.figure(figsize=(15,5))
sns.countplot(x="Price",data = sales)
# Out:
# <Axes: xlabel='Price', ylabel='count'>

# %%
sns.countplot(y="Rank",data = sales)
# Out:
# <Axes: xlabel='count', ylabel='Rank'>

# %%
plt.figure(figsize=(15,5))
sns.countplot(x="Price",data = sales,hue = "Rank")
# Out:
# <Axes: xlabel='Price', ylabel='count'>

# %%
plt.figure(figsize=(15,5))
sns.countplot(x="Price",data = sales,palette="tab20",facecolor=(1,1,1),edgecolor=sns.color_palette("bright",12))
# Out:
# <ipython-input-22-36c6eb7edd5e>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="Price",data = sales,palette="tab20",facecolor=(1,1,1),edgecolor=sns.color_palette("bright",12))
# <Axes: xlabel='Price', ylabel='count'>

# %%
data = np.random.random((10,10))
plt.imshow(data,cmap='hot',interpolation = 'nearest')
plt.title("Rank")
plt.colorbar()
plt.show()

# %%
sns.boxplot(x="Price",data = sales,width = 2)
# Out:
# <Axes: xlabel='Price'>
