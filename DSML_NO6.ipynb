# %% [markdown]
# <a href="https://colab.research.google.com/github/sahilnagarkar36/DSML-lab-manual/blob/main/DSML_NO6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
temperature = pd.read_csv('/content/temperatures.csv')

# %%
temperature.head()
# Out:
#    lat(deg)  lon(deg)  TinJan  TinFeb  TinMar  TinApr  TinMay  TinJun  TinJul  \
# 0       -90      -180     -26     -38     -50     -54     -55     -55     -57
# 1       -80      -180     -10     -20     -33     -37     -37     -38     -40
# 2       -70      -180      -1      -5     -11     -17     -19     -20     -22
# 3       -60      -180       8       8       8       7       5       4       4
# 4       -50      -180      11      11      10       9       8       6       6
#
#    TinAug  TinSep  TinOct  TinNov  TinDec
# 0     -55     -55     -48     -36     -26
# 1     -39     -38     -28     -18     -10
# 2     -22     -20     -15      -8      -2
# 3       4       4       5       5       7
# 4       6       7       8       9      11

# %%
temperature.tail()
# Out:
#      lat(deg)  lon(deg)  TinJan  TinFeb  TinMar  TinApr  TinMay  TinJun  \
# 698        50       180       1       1       1       3       5       7
# 699        60       180     -20     -22     -19     -13      -2       6
# 700        70       180     -22     -23     -22     -16      -5       1
# 701        80       180     -22     -24     -23     -16      -6       1
# 702        90       180     -32     -32     -32     -24     -10       0
#
#      TinJul  TinAug  TinSep  TinOct  TinNov  TinDec
# 698       9      11       9       6       3       1
# 699      11      10       4      -5     -13     -19
# 700       4       4       0      -6     -13     -20
# 701       4       3       0      -6     -14     -20
# 702       3       1      -7     -18     -26     -30

# %%
temperature.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 703 entries, 0 to 702
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   lat(deg)  703 non-null    int64
#  1   lon(deg)  703 non-null    int64
#  2   TinJan    703 non-null    int64
#  3   TinFeb    703 non-null    int64
#  4   TinMar    703 non-null    int64
#  5   TinApr    703 non-null    int64
#  6   TinMay    703 non-null    int64
#  7   TinJun    703 non-null    int64
#  8   TinJul    703 non-null    int64
#  9   TinAug    703 non-null    int64
#  10  TinSep    703 non-null    int64
#  11  TinOct    703 non-null    int64
#  12  TinNov    703 non-null    int64
#  13  TinDec    703 non-null    int64
# dtypes: int64(14)
# memory usage: 77.0 KB

# %%
temperature.shape
# Out:
# (703, 14)

# %%
temperature.describe()
# Out:
#          lat(deg)    lon(deg)      TinJan      TinFeb      TinMar      TinApr  \
# count  703.000000  703.000000  703.000000  703.000000  703.000000  703.000000
# mean     0.000000    0.000000    2.394026    1.283073    0.651494    1.856330
# std     54.811253  106.846803   21.002708   22.682582   24.443423   24.199153
# min    -90.000000 -180.000000  -41.000000  -42.000000  -55.000000  -60.000000
# 25%    -50.000000  -90.000000  -17.000000  -20.000000  -19.000000  -15.500000
# 50%      0.000000    0.000000    5.000000    5.000000    6.000000    8.000000
# 75%     50.000000   90.000000   23.000000   23.000000   23.000000   23.000000
# max     90.000000  180.000000   31.000000   31.000000   32.000000   33.000000
#
#            TinMay      TinJun      TinJul      TinAug      TinSep      TinOct  \
# count  703.000000  703.000000  703.000000  703.000000  703.000000  703.000000
# mean     4.000000    5.665718    6.162162    5.955903    4.779516    3.577525
# ...

# %%
temperature.plot(x='TinJan', y='TinJun', kind='scatter')
# Out:
# <Axes: xlabel='TinJan', ylabel='TinJun'>

# %%
temperature.isnull()
# Out:
#      lat(deg)  lon(deg)  TinJan  TinFeb  TinMar  TinApr  TinMay  TinJun  \
# 0       False     False   False   False   False   False   False   False
# 1       False     False   False   False   False   False   False   False
# 2       False     False   False   False   False   False   False   False
# 3       False     False   False   False   False   False   False   False
# 4       False     False   False   False   False   False   False   False
# ..        ...       ...     ...     ...     ...     ...     ...     ...
# 698     False     False   False   False   False   False   False   False
# 699     False     False   False   False   False   False   False   False
# 700     False     False   False   False   False   False   False   False
# 701     False     False   False   False   False   False   False   False
# 702     False     False   False   False   False   False   False   False
#
#      TinJul  TinAug  TinSep  TinOct  TinNov  TinDec
# ...

# %%
temperature.isnull().sum()
# Out:
# lat(deg)    0
# lon(deg)    0
# TinJan      0
# TinFeb      0
# TinMar      0
# TinApr      0
# TinMay      0
# TinJun      0
# TinJul      0
# TinAug      0
# TinSep      0
# TinOct      0
# TinNov      0
# TinDec      0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %%
x = temperature['TinApr'].values.reshape(-1,1)
y = temperature['TinAug'].values.reshape(-1,1)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 0)

# %%
regressor = LinearRegression()
regressor.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(x_test)

# %%
plt.scatter(x_test, y_test, color = 'yellow')
plt.plot(x_test, y_pred, color = 'red')
plt.show()

# %%
metrics.mean_absolute_error(y_test, y_pred)
# Out:
# 8.06846862804204

# %%
metrics.r2_score(y_test, y_pred)
# Out:
# 0.8410998361242319

# %%
metrics.mean_squared_error(y_test, y_pred)
# Out:
# 89.73043739201454
